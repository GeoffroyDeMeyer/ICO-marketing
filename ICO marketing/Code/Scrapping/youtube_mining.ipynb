# %%
from requests_html import HTMLSession
import numpy as np
import csv
import pandas as pd 
session = HTMLSession()

# %%
from pprint import pprint

# %%
with open('ICO_youtube.csv', 'w', newline='') as csvfile :
    ICO = pd.read_csv("/Users/GeoffroyDeMeyer/Desktop/Dathena/Projet/Dathena Network/CSV/ICO_github.csv")
    fieldnames = ['name', 'category', 'start', 'end', 'USD raised', 'USD aimed', 'ROI rate', 'accepted currency', 
                  'integrity', 'team', 'vision', 'critic video', 'video count', 'view count', 'comment count', 'subscriber count',
                  'product', 'marketing', 'community', 'risk', 'video', 'website', 'whitepaper', 'facebook', 'twitter',
                  'follower', 'following', 'total tweet', 'ICO tweet','instagram', 'linkedin', 'reddit', 'github', 
                  'github repositories', 'github repositories frequency','github commit', 'github commit frequency', 
                  'youtube channel', 'medium', 'bitcointalk', 'steemit', 'slack', 'CEO', 'cofounder', 'CTO', 'event', 
                  'youtube channel link']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    
    for k in range (0,len(ICO)) :
        data = { 'name' : ICO.iloc[k]['name'], 'category' : ICO.iloc[k]['category'], 'start' : ICO.iloc[k]['start'],
                'end' : ICO.iloc[k]['end'],'USD raised' : ICO.iloc[k]['USD raised'], 'USD aimed' : ICO.iloc[k]['USD aimed'], 
                'ROI rate' : ICO.iloc[k]['ROI rate'], 'accepted currency' : ICO.iloc[k]['accepted currency'],
                'integrity' : ICO.iloc[k]['integrity'], 'team' : ICO.iloc[k]['team'], 'vision' : ICO.iloc[k]['vision'],
                'product' : ICO.iloc[k]['product'], 'marketing' : ICO.iloc[k]['marketing'], 'community' : ICO.iloc[k]['community'], 
                'risk' : ICO.iloc[k]['risk'],'video': ICO.iloc[k]['video'], 'critic video' : 0, 'video count' : 0, 'view count' : 0, 
                'comment count' : 0, 'subscriber count' : 0,'website': ICO.iloc[k]['website'],
                'whitepaper': ICO.iloc[k]['whitepaper'], 'facebook' : ICO.iloc[k]['facebook'], 'twitter' : ICO.iloc[k]['twitter'], 
                'follower' : ICO.iloc[k]['follower'], 'following' : ICO.iloc[k]['following'], 'total tweet' : ICO.iloc[k]['total tweet'], 
                'ICO tweet' : ICO.iloc[k]['ICO tweet'], 'instagram' : ICO.iloc[k]['instagram'], 'linkedin' : ICO.iloc[k]['linkedin'], 
                'reddit' : ICO.iloc[k]['reddit'], 'github' : ICO.iloc[k]['github'], 'github repositories' : ICO.iloc[k]['github repositories'] , 
                'github repositories frequency' : ICO.iloc[k]['github repositories frequency'], 'github commit' : ICO.iloc[k]['github commit'], 
                'github commit frequency' : ICO.iloc[k]['github commit frequency'],'youtube channel' : ICO.iloc[k]['youtube channel'], 
                'medium' : ICO.iloc[k]['medium'], 'bitcointalk' : ICO.iloc[k]['bitcointalk'], 'steemit' : ICO.iloc[k]['steemit'], 
                'slack' : ICO.iloc[k]['slack'], 'CEO' : ICO.iloc[k]['CEO'], 'cofounder' : ICO.iloc[k]['cofounder'], 
                'CTO': ICO.iloc[k]['CTO'], 'event' : ICO.iloc[k]['event']}
        adress = 'https://www.googleapis.com/youtube/v3/search?q=' + str(ICO.iloc[k]['name']) +'+ICO' + '&key=AIzaSyDJ-yzbGYLPy2nxooGdIg1IIi4wsoOIads&part=snippet'
        r = session.get(adress)
        res = r.json()
        res = res['pageInfo']['totalResults']
        data['critic video'] += res
        
        
        id = ICO.iloc[k]['youtube channel link'].replace('https://www.youtube.com/channel/','')
        adress = 'https://www.googleapis.com/youtube/v3/channels?' +  '&key=AIzaSyDJ-yzbGYLPy2nxooGdIg1IIi4wsoOIads&part=statistics&id=' + str(id)
        r = session.get(adress)
        res = r.json()
        if res['items'] != [] :
            res = res['items'][0]['statistics']
            data['view count'] += int(res['viewCount'])
            data['comment count'] += int(res['commentCount'])
            data['subscriber count'] += int(res['subscriberCount'])
            data['video count'] += int(res['videoCount'])
            print(data['video count'])

        
        writer.writerow(data)
# Out:
# 9
# 7
# 8
# 3
# 17
# 223
# 1
# 4
# 4
# 9
# 3
# 9
# 19
# 15
# 33
# 70
# 17
# 18
# 3
# 10
# 3
# 9
# 16
# 16
# 0
# 10
# 8
# 8
# 26
# 16
# 11
# 10
# 46
# 5
# 34
# 87
# 6
# 10
# 12
# 6
# 8
# 9
# 5
# 8
# 5
# 26
# 39
# 8
# 147
# 57
# 23
# 0
# 20
# 25
# 19
# 14
# 7
# 18
# 6
# 1
# 10
# 26
# 24
# 4
# 4
# 15
# 11
# 44
# 28
# 46
# 25
# 9
# 1
# 6
# 8
# 4
# 9
# 8
# 17
# 31
# 5
# 13
# 19
# 87
# 29
# 41
# 19
# 291
# 20
# 48
# 11
# 2
# 56
# 20
# 4
# 38
# 11
# 1
# 9
# 71
# 21
# 9
# 2
# 32
# 13
# 33
# 2
# 63
# 18
# 7
# 41
# 24
# 5
# 16
# 39
# 13
# 6
# 13
# 14
# 3
# 11
# 33
# 8
# 8
# 16
# 2
# 34
# 27
# 44
# 9
# 30
# 27
# 9
# 7
# 13
# 15
# 4
# 17
# 4
# 30
# 19
# 3
# 2
# 71
# 13
# 18
# 27
# 3
# 9
# 47
# 11
# 4
# 149
# 21
# 59
# 2
# 111
# 4
# 10
# 28
# 38
# 25
# 35
# 29
# 44
# 24
# 10
# 13
# 6
# 47
# 147
# 11
# 7
# 4
# 33
# 10
# 9
# 125
# 2
# 6
# 31
# 7
# 45
# 53
# 2
# 4
# 7
# 36
# 17
# 58
# 11
# 6
# 11
# 18
# 30
# 12
# 14
# 26
# 22
# 4
# 18
# 46
# 122
# 12
# 20
# 6
# 17
# 2
# 9
# 5
# 19
# 13
# 27
# 1
# 6
# ...

# %%
adress = 'https://www.googleapis.com/youtube/v3/channels?' +  '&key=AIzaSyDJ-yzbGYLPy2nxooGdIg1IIi4wsoOIads&part=statistics&id=UCSvXPpv3mQgOc0C2XFYLfWg'

# %%
r = session.get(adress)
res = r.json()
print(res['items'][0]['statistics'])
# Out:
# {'viewCount': '793', 'commentCount': '0', 'subscriberCount': '1938', 'hiddenSubscriberCount': False, 'videoCount': '3'}
